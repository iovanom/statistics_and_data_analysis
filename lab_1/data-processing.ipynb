# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./dataset/results.csv')

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.describe(include="all")
# Out:
#               date home_team away_team    home_score    away_score tournament  \
# count        48532     48532     48532  48532.000000  48532.000000      48532
# unique       16348       325       318           NaN           NaN        188
# top     2012-02-29    Brazil   Uruguay           NaN           NaN   Friendly
# freq            66       608       578           NaN           NaN      18116
# mean           NaN       NaN       NaN      1.758180      1.181550        NaN
# std            NaN       NaN       NaN      1.773101      1.400946        NaN
# min            NaN       NaN       NaN      0.000000      0.000000        NaN
# 25%            NaN       NaN       NaN      1.000000      0.000000        NaN
# 50%            NaN       NaN       NaN      1.000000      1.000000        NaN
# 75%            NaN       NaN       NaN      2.000000      2.000000        NaN
# max            NaN       NaN       NaN     31.000000     21.000000        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48532 entries, 0 to 48531
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        48532 non-null  object
#  1   home_team   48532 non-null  object
#  2   away_team   48532 non-null  object
#  3   home_score  48532 non-null  int64
#  4   away_score  48532 non-null  int64
#  5   tournament  48532 non-null  object
#  6   city        48532 non-null  object
#  7   country     48532 non-null  object
#  8   neutral     48532 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 3.0+ MB

# %%
df.isnull()
# Out:
#         date  home_team  away_team  home_score  away_score  tournament   city  \
# 0      False      False      False       False       False       False  False
# 1      False      False      False       False       False       False  False
# 2      False      False      False       False       False       False  False
# 3      False      False      False       False       False       False  False
# 4      False      False      False       False       False       False  False
# ...      ...        ...        ...         ...         ...         ...    ...
# 48527  False      False      False       False       False       False  False
# 48528  False      False      False       False       False       False  False
# 48529  False      False      False       False       False       False  False
# 48530  False      False      False       False       False       False  False
# 48531  False      False      False       False       False       False  False
#
#        country  neutral
# ...

# %%
df.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df.shape
# Out:
# (48532, 9)

# %%
df.dtypes
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %%
df['home_team']
# Out:
# 0                      Scotland
# 1                       England
# 2                      Scotland
# 3                       England
# 4                      Scotland
#                   ...
# 48527    Bosnia and Herzegovina
# 48528                    Cyprus
# 48529                    Norway
# 48530                   Albania
# 48531                    Serbia
# Name: home_team, Length: 48532, dtype: object

# %%
df[['home_team', 'away_team']]
# Out:
#                     home_team away_team
# 0                    Scotland   England
# 1                     England  Scotland
# 2                    Scotland   England
# 3                     England  Scotland
# 4                    Scotland   England
# ...                       ...       ...
# 48527  Bosnia and Herzegovina   Austria
# 48528                  Cyprus   Romania
# 48529                  Norway   Moldova
# 48530                 Albania    Latvia
# 48531                  Serbia   England
#
# [48532 rows x 2 columns]

# %%
set(df['tournament'])
# Out:
# {'ABCS Tournament',
#  'AFC Asian Cup',
#  'AFC Asian Cup qualification',
#  'AFC Challenge Cup',
#  'AFC Challenge Cup qualification',
#  'AFF Championship',
#  'AFF Championship qualification',
#  'ASEAN Championship',
#  'ASEAN Championship qualification',
#  'African Cup of Nations',
#  'African Cup of Nations qualification',
#  'African Friendship Games',
#  'Afro-Asian Games',
#  'All-African Games',
#  'Amílcar Cabral Cup',
#  'Arab Cup',
#  'Arab Cup qualification',
#  'Asian Games',
#  'Atlantic Cup',
#  'Atlantic Heritage Cup',
#  'Balkan Cup',
#  'Baltic Cup',
#  'Beijing International Friendship Tournament',
#  'Benedikt Fontana Cup',
#  'Bolivarian Games',
#  'Brazil Independence Cup',
#  'British Home Championship',
#  'CAFA Nations Cup',
#  'CCCF Championship',
#  'CECAFA Cup',
#  'CFU Caribbean Cup',
#  'CFU Caribbean Cup qualification',
#  'CONCACAF Championship',
#  'CONCACAF Championship qualification',
#  'CONCACAF Nations League',
# ...

# %%
df[df['tournament'] == 'Brazil Independence Cup'].head()
# Out:
#             date home_team            away_team  home_score  away_score  \
# 8873  1972-06-11   Bolivia                 Peru           0           3
# 8875  1972-06-11   Ecuador             Portugal           0           3
# 8876  1972-06-11      Iran  Republic of Ireland           1           2
# 8877  1972-06-11  Paraguay            Venezuela           4           1
# 8881  1972-06-14     Chile              Ecuador           2           1
#
#                    tournament          city country  neutral
# 8873  Brazil Independence Cup      Curitiba  Brazil     True
# 8875  Brazil Independence Cup         Natal  Brazil     True
# 8876  Brazil Independence Cup        Recife  Brazil     True
# 8877  Brazil Independence Cup  Campo Grande  Brazil     True
# 8881  Brazil Independence Cup         Natal  Brazil     True

# %%
df.loc[[5, 100, 1000], ['home_team', 'away_team', 'tournament']]
# Out:
#         home_team    away_team                 tournament
# 5        Scotland        Wales                   Friendly
# 100         Wales     Scotland  British Home Championship
# 1000  Switzerland  Netherlands                   Friendly

# %%
df_t = df[(df['tournament'] == 'UEFA Euro') | (df['tournament'] == 'FIFA World Cup')]

# %%
df_t.tail()
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 47415  2024-07-06      England  Switzerland           1           1
# 47416  2024-07-06  Netherlands       Turkey           2           1
# 47419  2024-07-09        Spain       France           2           1
# 47421  2024-07-10  Netherlands      England           1           2
# 47424  2024-07-14        Spain      England           2           1
#
#       tournament        city  country  neutral
# 47415  UEFA Euro  Düsseldorf  Germany     True
# 47416  UEFA Euro      Berlin  Germany     True
# 47419  UEFA Euro      Munich  Germany     True
# 47421  UEFA Euro    Dortmund  Germany     True
# 47424  UEFA Euro      Berlin  Germany     True

# %%
df_t.head()
# Out:
#             date  home_team      away_team  home_score  away_score  \
# 1486  1930-07-13    Belgium  United States           0           3
# 1487  1930-07-13     France         Mexico           4           1
# 1488  1930-07-14     Brazil     Yugoslavia           1           2
# 1489  1930-07-14       Peru        Romania           1           3
# 1490  1930-07-15  Argentina         France           1           0
#
#           tournament        city  country  neutral
# 1486  FIFA World Cup  Montevideo  Uruguay     True
# 1487  FIFA World Cup  Montevideo  Uruguay     True
# 1488  FIFA World Cup  Montevideo  Uruguay     True
# 1489  FIFA World Cup  Montevideo  Uruguay     True
# 1490  FIFA World Cup  Montevideo  Uruguay     True

# %%
df_t.sort_values('home_score').head()
# Out:
#              date    home_team away_team  home_score  away_score  \
# 26495  2002-06-25  South Korea   Germany           0           1
# 26493  2002-06-22      Senegal    Turkey           0           1
# 26492  2002-06-22  South Korea     Spain           0           0
# 47371  2024-06-24      Albania     Spain           0           1
# 47368  2024-06-23     Scotland   Hungary           0           1
#
#            tournament        city      country  neutral
# 26495  FIFA World Cup       Seoul  South Korea    False
# 26493  FIFA World Cup       Osaka        Japan     True
# 26492  FIFA World Cup     Gwangju  South Korea    False
# 47371       UEFA Euro  Düsseldorf      Germany     True
# 47368       UEFA Euro   Stuttgart      Germany     True

# %%
df_t.sort_values(['home_score', 'away_score'], ascending=[False, True]).head()
# Out:
#              date   home_team     away_team  home_score  away_score  \
# 13298  1982-06-15     Hungary   El Salvador          10           1
# 3958   1954-06-17     Hungary   South Korea           9           0
# 9775   1974-06-18  Yugoslavia      DR Congo           9           0
# 26430  2002-06-01     Germany  Saudi Arabia           8           0
# 33892  2010-06-21    Portugal   North Korea           7           0
#
#            tournament           city       country  neutral
# 13298  FIFA World Cup          Elche         Spain     True
# 3958   FIFA World Cup         Zürich   Switzerland     True
# 9775   FIFA World Cup  Gelsenkirchen       Germany     True
# 26430  FIFA World Cup        Sapporo         Japan     True
# 33892  FIFA World Cup      Cape Town  South Africa     True

# %%
df[df['home_score'] == df['away_score']]
# Out:
#              date         home_team    away_team  home_score  away_score  \
# 0      1872-11-30          Scotland      England           0           0
# 3      1875-03-06           England     Scotland           2           2
# 28     1883-03-17  Northern Ireland        Wales           1           1
# 36     1885-03-14           England        Wales           1           1
# 38     1885-03-21           England     Scotland           1           1
# ...           ...               ...          ...         ...         ...
# 48512  2025-09-09        Mauritania  South Sudan           0           0
# 48514  2025-09-09      South Africa      Nigeria           1           1
# 48520  2025-09-09             Gabon  Ivory Coast           0           0
# 48523  2025-09-09        Azerbaijan      Ukraine           1           1
# 48528  2025-09-09            Cyprus      Romania           2           2
#
#                          tournament          city       country  neutral
# ...

# %%
df[df['tournament'] == 'Friendly'].sort_values('date')
# Out:
#              date      home_team           away_team  home_score  away_score  \
# 0      1872-11-30       Scotland             England           0           0
# 1      1873-03-08        England            Scotland           4           2
# 2      1874-03-07       Scotland             England           2           1
# 3      1875-03-06        England            Scotland           2           2
# 4      1876-03-04       Scotland             England           3           0
# ...           ...            ...                 ...         ...         ...
# 48501  2025-09-09  United States               Japan           2           0
# 48495  2025-09-09         Jordan  Dominican Republic           3           0
# 48494  2025-09-09        Estonia             Andorra           0           0
# 48496  2025-09-09          Malta          San Marino           3           1
# 48502  2025-09-09          Wales              Canada           0           1
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=48532, step=1)

# %%
mdf = df.copy(deep=True)

# %%
mdf['total_score'] = mdf['home_score'] + mdf['away_score']

# %%
mdf.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  total_score
# 0  Scotland    False            0
# 1   England    False            6
# 2  Scotland    False            3
# 3   England    False            4
# 4  Scotland    False            3

# %%
mdf['home_win'] = np.sign(mdf['home_score'] - mdf['away_score']).astype('Int8')

# %%
mdf.head(10)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
# 5  1876-03-25  Scotland     Wales           4           0   Friendly  Glasgow
# 6  1877-03-03   England  Scotland           1           3   Friendly   London
# 7  1877-03-05     Wales  Scotland           0           2   Friendly  Wrexham
# 8  1878-03-02  Scotland   England           7           2   Friendly  Glasgow
# 9  1878-03-23  Scotland     Wales           9           0   Friendly  Glasgow
#
#     country  neutral  total_score  home_win
# 0  Scotland    False            0         0
# ...

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48532 entries, 0 to 48531
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         48532 non-null  object
#  1   home_team    48532 non-null  object
#  2   away_team    48532 non-null  object
#  3   home_score   48532 non-null  int64
#  4   away_score   48532 non-null  int64
#  5   tournament   48532 non-null  object
#  6   city         48532 non-null  object
#  7   country      48532 non-null  object
#  8   neutral      48532 non-null  bool
#  9   total_score  48532 non-null  int64
#  10  home_win     48532 non-null  Int8
# dtypes: Int8(1), bool(1), int64(3), object(6)
# memory usage: 3.5+ MB

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
germany = mdf[(mdf.home_team == 'Germany') | (mdf.away_team == 'Germany')]
germany.count()
# Out:
# date           1023
# home_team      1023
# away_team      1023
# home_score     1023
# away_score     1023
# tournament     1023
# city           1023
# country        1023
# neutral        1023
# total_score    1023
# home_win       1023
# dtype: int64

# %%
germany.total_score.mean(), germany.total_score.median()
# Out:
# (np.float64(3.409579667644184), np.float64(3.0))

# %%
germany.total_score.mode()
# Out:
# 0    2
# Name: total_score, dtype: int64

# %%
germany.total_score.describe()
# Out:
# count    1023.000000
# mean        3.409580
# std         2.180546
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        16.000000
# Name: total_score, dtype: float64

# %%
res = mdf.groupby(['home_team', 'away_team'])['home_score'].agg('max')

# %%
res.France.sort_values()
# Out:
# away_team
# Corsica          0
# Canada           0
# Senegal          0
# Burkina Faso     1
# Peru             1
#                 ..
# Iceland          8
# Kazakhstan       8
# Azerbaijan      10
# Greece          11
# Gibraltar       14
# Name: home_score, Length: 90, dtype: int64

# %%
mdf['total_score'].plot(kind='hist', bins=60, xlim=[0, 15])
# Out:
# <Axes: ylabel='Frequency'>

# %%
mdf.total_score.plot(kind='kde', xlim=[0, 20])
# Out:
# <Axes: ylabel='Density'>

# %%
mdf.groupby('home_team').total_score.plot(kind='hist', xlim=[0, 20])
# Out:
# home_team
# Abkhazia         Axes(0.125,0.11;0.775x0.77)
# Afghanistan      Axes(0.125,0.11;0.775x0.77)
# Albania          Axes(0.125,0.11;0.775x0.77)
# Alderney         Axes(0.125,0.11;0.775x0.77)
# Algeria          Axes(0.125,0.11;0.775x0.77)
#                             ...
# Yugoslavia       Axes(0.125,0.11;0.775x0.77)
# Zambia           Axes(0.125,0.11;0.775x0.77)
# Zanzibar         Axes(0.125,0.11;0.775x0.77)
# Zimbabwe         Axes(0.125,0.11;0.775x0.77)
# Åland Islands    Axes(0.125,0.11;0.775x0.77)
# Name: total_score, Length: 325, dtype: object

# %%
mdf.total_score.value_counts()
# Out:
# total_score
# 2     10772
# 3      9597
# 1      8403
# 4      6722
# 5      4176
# 0      3896
# 6      2272
# 7      1238
# 8       634
# 9       353
# 10      183
# 11       99
# 12       63
# 13       36
# 14       23
# 15       14
# 16       13
# 18       11
# 17       10
# 19        5
# 20        4
# 21        3
# 22        2
# 30        1
# 24        1
# 31        1
# Name: count, dtype: int64

# %%
mdf['score'] = mdf['home_score'].astype('string').str.cat(df['away_score'].astype('string'), sep=':')

# %%
mdf.score.value_counts()
# Out:
# score
# 1:0     5017
# 1:1     4817
# 0:0     3896
# 2:0     3771
# 2:1     3714
#         ...
# 22:0       1
# 31:0       1
# 0:21       1
# 21:1       1
# 17:1       1
# Name: count, Length: 134, dtype: Int64

# %%
df.describe()
# Out:
#          home_score    away_score
# count  48532.000000  48532.000000
# mean       1.758180      1.181550
# std        1.773101      1.400946
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df
# Out:
#              date               home_team away_team  home_score  away_score  \
# 0      1872-11-30                Scotland   England           0           0
# 1      1873-03-08                 England  Scotland           4           2
# 2      1874-03-07                Scotland   England           2           1
# 3      1875-03-06                 England  Scotland           2           2
# 4      1876-03-04                Scotland   England           3           0
# ...           ...                     ...       ...         ...         ...
# 48527  2025-09-09  Bosnia and Herzegovina   Austria           1           2
# 48528  2025-09-09                  Cyprus   Romania           2           2
# 48529  2025-09-09                  Norway   Moldova          11           1
# 48530  2025-09-09                 Albania    Latvia           1           0
# 48531  2025-09-09                  Serbia   England           0           5
#
# ...

# %%
df.groupby('tournament')['home_score'].agg('sum')
# Out:
# tournament
# ABCS Tournament                      43
# AFC Asian Cup                       630
# AFC Asian Cup qualification        1774
# AFC Challenge Cup                   142
# AFC Challenge Cup qualification     175
#                                    ...
# West African Cup                     74
# Windward Islands Tournament         178
# World Unity Cup                       3
# Zambian Independence Tournament       5
# Évence Coppée Trophy                  3
# Name: home_score, Length: 188, dtype: int64

# %%
df['score'] = np.sign(df['home_score'] - df['away_score']).astype('Int8')

# %%
df['score_repr'] = df['home_score'].astype('string').str.cat(df['away_score'].astype('string'), sep=':')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48532 entries, 0 to 48531
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        48532 non-null  object
#  1   home_team   48532 non-null  object
#  2   away_team   48532 non-null  object
#  3   home_score  48532 non-null  int64
#  4   away_score  48532 non-null  int64
#  5   tournament  48532 non-null  object
#  6   city        48532 non-null  object
#  7   country     48532 non-null  object
#  8   neutral     48532 non-null  bool
#  9   score       48532 non-null  Int8
#  10  score_repr  48532 non-null  string
# dtypes: Int8(1), bool(1), int64(2), object(6), string(1)
# memory usage: 3.5+ MB

# %%
df.groupby('home_team')['home_score'].mean().to_frame('avg_score').reset_index().sort_values('avg_score', ascending = False)
# Out:
#               home_team  avg_score
# 216  Parishes of Jersey        5.5
# 124               Hmong        5.0
# 84          Elba Island        5.0
# 49             Cascadia        5.0
# 98            Franconia        4.0
# ..                  ...        ...
# 197                Niue        0.0
# 74               Darfur        0.0
# 232              Ryūkyū        0.0
# 245                Sark        0.0
# 18               Aymara        0.0
#
# [325 rows x 2 columns]

# %%
df.groupby('home_team', as_index=False)['home_score'].mean()
# Out:
#          home_team  home_score
# 0         Abkhazia    1.772727
# 1      Afghanistan    1.170213
# 2          Albania    1.140777
# 3         Alderney    0.416667
# 4          Algeria    1.894118
# ..             ...         ...
# 320     Yugoslavia    2.310526
# 321         Zambia    1.899696
# 322       Zanzibar    1.080645
# 323       Zimbabwe    1.610000
# 324  Åland Islands    1.612903
#
# [325 rows x 2 columns]

# %%
df.groupby(['home_team', 'away_team'])[['home_score', 'away_score']].sum().reset_index()
# Out:
#            home_team       away_team  home_score  away_score
# 0           Abkhazia         Artsakh           1           1
# 1           Abkhazia  Chagos Islands           9           0
# 2           Abkhazia        Chameria           3           1
# 3           Abkhazia      Donetsk PR           2           2
# 4           Abkhazia      Kárpátalja           0           2
# ...              ...             ...         ...         ...
# 12031  Åland Islands    Saare County           3           3
# 12032  Åland Islands         Sealand           2           2
# 12033  Åland Islands        Shetland           9           3
# 12034  Åland Islands   Western Isles           0           2
# 12035  Åland Islands        Ynys Môn           4           6
#
# [12036 rows x 4 columns]

# %%
sh = pd.read_csv('./dataset/shootouts.csv')
sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653 entries, 0 to 652
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           653 non-null    object
#  1   home_team      653 non-null    object
#  2   away_team      653 non-null    object
#  3   winner         653 non-null    object
#  4   first_shooter  236 non-null    object
# dtypes: object(5)
# memory usage: 25.6+ KB

# %%
sh.head()
# Out:
#          date    home_team         away_team       winner first_shooter
# 0  1967-08-22        India            Taiwan       Taiwan           NaN
# 1  1971-11-14  South Korea  Vietnam Republic  South Korea           NaN
# 2  1972-05-07  South Korea              Iraq         Iraq           NaN
# 3  1972-05-17     Thailand       South Korea  South Korea           NaN
# 4  1972-05-19     Thailand          Cambodia     Thailand           NaN

# %%
sh.tail()
# Out:
#            date                     home_team                 away_team  \
# 648  2025-06-29                        Canada                 Guatemala
# 649  2025-06-29                 United States                Costa Rica
# 650  2025-07-13                          Gozo                  Shetland
# 651  2025-07-17                          Gozo             Western Isles
# 652  2025-08-13  United States Virgin Islands  Turks and Caicos Islands
#
#                            winner first_shooter
# 648                     Guatemala        Canada
# 649                 United States    Costa Rica
# 650                          Gozo          Gozo
# 651                          Gozo           NaN
# 652  United States Virgin Islands           NaN

# %%
fm = pd.read_csv('./dataset/former_names.csv')
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   current     34 non-null     object
#  1   former      34 non-null     object
#  2   start_date  34 non-null     object
#  3   end_date    34 non-null     object
# dtypes: object(4)
# memory usage: 1.2+ KB

# %% [markdown]
# fm.head()

# %%
fm.head()
# Out:
#           current                former  start_date    end_date
# 0           Benin               Dahomey  1959-11-08  1975-11-30
# 1    Burkina Faso           Upper Volta  1960-04-14  1984-08-04
# 2         Curaçao  Netherlands Antilles  1957-03-03  2010-10-10
# 3  Czechoslovakia               Bohemia  1903-04-05  1919-01-01
# 4  Czechoslovakia   Bohemia and Moravia  1939-01-01  1945-05-01

# %%
fm.tail()
# Out:
#      current             former  start_date    end_date
# 29  Suriname       Dutch Guyana  1921-01-28  1975-11-25
# 30  Tanzania         Tanganyika  1945-01-01  1964-04-26
# 31   Vanuatu       New Hebrides  1951-10-04  1980-07-30
# 32    Zambia  Northern Rhodesia  1947-02-22  1964-10-25
# 33  Zimbabwe  Southern Rhodesia  1946-06-16  1980-04-18

# %%
gs = pd.read_csv('./dataset/goalscorers.csv')
gs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44447 entries, 0 to 44446
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       44447 non-null  object
#  1   home_team  44447 non-null  object
#  2   away_team  44447 non-null  object
#  3   team       44447 non-null  object
#  4   scorer     44399 non-null  object
#  5   minute     44191 non-null  float64
#  6   own_goal   44447 non-null  bool
#  7   penalty    44447 non-null  bool
# dtypes: bool(2), float64(1), object(5)
# memory usage: 2.1+ MB

# %%
gs.head()
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %%
gs.count()
# Out:
# date         44447
# home_team    44447
# away_team    44447
# team         44447
# scorer       44399
# minute       44191
# own_goal     44447
# penalty      44447
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48532 entries, 0 to 48531
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        48532 non-null  object
#  1   home_team   48532 non-null  object
#  2   away_team   48532 non-null  object
#  3   home_score  48532 non-null  int64
#  4   away_score  48532 non-null  int64
#  5   tournament  48532 non-null  object
#  6   city        48532 non-null  object
#  7   country     48532 non-null  object
#  8   neutral     48532 non-null  bool
#  9   score       48532 non-null  Int8
#  10  score_repr  48532 non-null  string
# dtypes: Int8(1), bool(1), int64(2), object(6), string(1)
# memory usage: 3.5+ MB

# %%
df['total_score'] = df['home_score'] + df['away_score']

# %%
df['total_score'].sum()
# Out:
# np.int64(142671)

# %%
pl = pd.read_csv('./dataset/players_data-2024_2025.csv')
pl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2854 entries, 0 to 2853
# Columns: 267 entries, Rk to AvgDist
# dtypes: float64(111), int64(121), object(35)
# memory usage: 5.8+ MB

# %%
pl.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts',
#        ...
#        'Att (GK)', 'Thr', 'Launch%', 'AvgLen', 'Opp', 'Stp', 'Stp%', '#OPA',
#        '#OPA/90', 'AvgDist'],
#       dtype='object', length=267)

# %%
df.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 df.size()
#
# TypeError: 'int' object is not callable

# %%
df.size
# Out:
# 582384

# %%
pl.size
# Out:
# 762018

# %%
pl.colums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_19100/2169130492.py in ?()
# ----> 1 pl.colums
#
# ~/.mamba/envs/Playground/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
pl.colums()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_19100/2792169120.py in ?()
# ----> 1 pl.colums()
#
# ~/.mamba/envs/Playground/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
pl.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 pl.columns()
#
# TypeError: 'Index' object is not callable

# %%
pl.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts',
#        ...
#        'Att (GK)', 'Thr', 'Launch%', 'AvgLen', 'Opp', 'Stp', 'Stp%', '#OPA',
#        '#OPA/90', 'AvgDist'],
#       dtype='object', length=267)

# %%
em = pd.read_csv('./dataset/combined_matches.csv')
em.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216883 entries, 0 to 216882
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   League     216883 non-null  object
#  1   Date       216883 non-null  object
#  2   HomeTeam   216883 non-null  object
#  3   AwayTeam   216883 non-null  object
#  4   HomeGoals  216883 non-null  float64
#  5   AwayGoals  216883 non-null  float64
#  6   Result     216883 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 11.6+ MB

# %%
em.size
# Out:
# 1518181

# %%
em.shape
# Out:
# (216883, 7)

# %%
help(em.shape)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
df = pd.read_csv('./dataset/results.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48532 entries, 0 to 48531
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        48532 non-null  object
#  1   home_team   48532 non-null  object
#  2   away_team   48532 non-null  object
#  3   home_score  48532 non-null  int64
#  4   away_score  48532 non-null  int64
#  5   tournament  48532 non-null  object
#  6   city        48532 non-null  object
#  7   country     48532 non-null  object
#  8   neutral     48532 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 3.0+ MB

# %%
df.shape
# Out:
# (48532, 9)
